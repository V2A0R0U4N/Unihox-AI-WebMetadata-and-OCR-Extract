# %%
# Install required packages (Colab only)
# !pip install aiohttp aiofiles pymupdf paddleocr bs4 nest-asyncio python-magic pytesseract -q
# !sudo apt-get install tesseract-ocr tesseract-ocr-san tesseract-ocr-hin libmagic1 -y
# !wget https://github.com/tesseract-ocr/tessdata/raw/main/san.traineddata -P /usr/share/tesseract-ocr/4.00/tessdata/

import os, aiohttp, aiofiles, asyncio, hashlib, re, json, fitz, magic, tempfile
from urllib.parse import urlparse, urljoin
from datetime import datetime
from bs4 import BeautifulSoup
from paddleocr import PaddleOCR
from google.colab import drive
import nest_asyncio
import pytesseract
from PIL import Image

# Setup
nest_asyncio.apply()
drive.mount("/content/drive")

# CONFIG
BASE_URLS = [
    "https://ayushportal.nic.in/default.aspx"
]
DOWNLOAD_DIR = "/content/drive/MyDrive/sanskritdocs/downloads"
OUTPUT_DIR = "/content/drive/MyDrive/sanskritdocs/outputs"
os.makedirs(DOWNLOAD_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# CONSTANTS
DOC_REGEX = re.compile(r'.*\.(pdf|epub|docx?|txt)$', re.IGNORECASE)
HEADERS = {"User-Agent": "Mozilla/5.0"}
sem = asyncio.Semaphore(2)
mime = magic.Magic(mime=True)

# Initialize OCR engines
try:
    paddle_ocr = PaddleOCR(use_angle_cls=True, lang='en', show_log=False)  # English
except:
    paddle_ocr = None

class SanskritCrawler:
    def __init__(self):
        self.session = None
        self.visited = set()
        self.found_docs = set()

    def log(self, msg):
        print(f"[{datetime.now().strftime('%H:%M:%S')}] {msg}")

    async def fetch(self, url):
        try:
            async with sem:
                async with self.session.get(url, headers=HEADERS, timeout=30) as r:
                    if r.status == 200 and 'html' in r.headers.get("Content-Type", ""):
                        return await r.text()
        except Exception as e:
            self.log(f"Fetch error: {url} - {str(e)}")
        return ""

    async def crawl(self, url, depth=2):
        if url in self.visited or depth <= 0:
            return
        self.visited.add(url)
        html = await self.fetch(url)
        if not html:
            return
        soup = BeautifulSoup(html, 'html.parser')
        for tag in soup.find_all('a', href=True):
            href = tag['href'].strip()
            full = urljoin(url, href)
            if DOC_REGEX.search(full):
                if full not in self.found_docs:
                    self.found_docs.add(full)
                    self.log(f"📄 Found: {full}")
            elif urlparse(full).netloc == urlparse(url).netloc:
                await self.crawl(full, depth - 1)

    async def download(self, url):
        fname = os.path.basename(urlparse(url).path)
        path = os.path.join(DOWNLOAD_DIR, fname)
        if os.path.exists(path):
            return path
        try:
            async with sem:
                async with self.session.get(url, timeout=60) as r:
                    if r.status == 200:
                        async with aiofiles.open(path, 'wb') as f:
                            await f.write(await r.read())
                        return path
        except Exception as e:
            self.log(f"❌ Download failed: {url} -> {e}")
        return ""

    def extract_text(self, path):
        try:
            # First try direct text extraction
            doc = fitz.open(path)
            full = "\n".join([p.get_text() for p in doc if p.get_text().strip()])
            if full.strip():
                return full

            self.log("🔍 No text found, using OCR")
            return self.run_ocr(path)
        except Exception as e:
            self.log(f"Text extraction error: {e}")
            return self.run_ocr(path)

    def run_ocr(self, path):
        text = ""
        try:
            doc = fitz.open(path)
            for pg in doc:
                pix = pg.get_pixmap(dpi=200)
                with tempfile.NamedTemporaryFile(suffix=".png") as tmp:
                    pix.save(tmp.name)

                    # Try PaddleOCR (English)
                    if paddle_ocr:
                        try:
                            paddle_result = paddle_ocr.ocr(tmp.name, cls=True)
                            if paddle_result and paddle_result[0]:
                                page_text = "\n".join([line[1][0] for line in paddle_result[0]])
                                text += page_text + "\n"
                                continue
                        except:
                            pass

                    # Fallback to Tesseract (Sanskrit)
                    img = Image.open(tmp.name)
                    try:
                        tesseract_text = pytesseract.image_to_string(img, lang='san')
                        text += tesseract_text + "\n"
                    except:
                        # Final fallback to English
                        tesseract_text = pytesseract.image_to_string(img, lang='eng')
                        text += tesseract_text + "\n"

        except Exception as e:
            self.log(f"OCR failed: {e}")
        return text.strip()

    def extract_meta(self, path, url):
        doc_id = hashlib.sha256(url.encode()).hexdigest()[:10]
        base = os.path.basename(path)
        try:
            doc = fitz.open(path)
            info = doc.metadata
        except:
            info = {}
        year = ""
        if info.get("creationDate", "").startswith("D:"):
            year = info["creationDate"][2:6]
        return {
            "site": urlparse(url).netloc,
            "document_id": doc_id,
            "title": info.get("title") or base,
            "authors": [info.get("author")] if info.get("author") else [],
            "pub_year": year,
            "language": "Sanskrit",
            "download_url": url,
            "scraped_at": datetime.utcnow().isoformat() + "Z",
            "checksum": self.sha256(path),
            "content": self.extract_text(path)
        }

    def sha256(self, path):
        h = hashlib.sha256()
        with open(path, 'rb') as f:
            for chunk in iter(lambda: f.read(4096), b""):
                h.update(chunk)
        return h.hexdigest()

    async def process_doc(self, url):
        path = await self.download(url)
        if not path:
            return
        meta = self.extract_meta(path, url)
        out_path = os.path.join(OUTPUT_DIR, f"{meta['document_id']}.json")
        with open(out_path, 'w', encoding='utf-8') as f:
            json.dump(meta, f, indent=2, ensure_ascii=False)
        self.log(f"📝 Saved: {out_path}")

    async def run(self):
        async with aiohttp.ClientSession() as s:
            self.session = s
            self.log("🚀 Starting crawl...")
            await asyncio.gather(*(self.crawl(url, depth=2) for url in BASE_URLS))
            self.log(f"📚 Total found: {len(self.found_docs)}")
            await asyncio.gather(*(self.process_doc(url) for url in self.found_docs))
            self.log("✅ Done.")

# Run it
await SanskritCrawler().run()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 78.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# libmagic1 is already the newest version (1:5.41-3ubuntu0.1).
# libmagic1 set to manually installed.
# The following NEW packages will be installed:
#   tesseract-ocr-hin tesseract-ocr-san
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 5,141 kB of archives.
# After this operation, 13.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-hin all 1:4.00~git30-7274cfa-1.1 [913 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-san all 1:4.00~git30-7274cfa-1.1 [4,228 kB]
# Fetched 5,141 kB in 0s (24.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-hin.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-hin_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-san.
# Preparing to unpack .../tesseract-ocr-san_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-san (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-san (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...
# --2025-07-15 06:06:15--  https://github.com/tesseract-ocr/tessdata/raw/main/san.traineddata
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tesseract-ocr/tessdata/main/san.traineddata [following]
# --2025-07-15 06:06:16--  https://raw.githubusercontent.com/tesseract-ocr/tessdata/main/san.traineddata
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12404680 (12M) [application/octet-stream]
# Saving to: ‘/usr/share/tesseract-ocr/4.00/tessdata/san.traineddata.1’
#
# san.traineddata.1   100%[===================>]  11.83M  --.-KB/s    in 0.04s
#
# 2025-07-15 06:06:16 (323 MB/s) - ‘/usr/share/tesseract-ocr/4.00/tessdata/san.traineddata.1’ saved [12404680/12404680]
#
# Mounted at /content/drive
# /tmp/ipython-input-1-3504901353.py:37: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   paddle_ocr = PaddleOCR(use_angle_cls=True, lang='en', show_log=False)  # English
# [06:06:46] 🚀 Starting crawl...
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Compendium_of_select_research_publications_on_the_Ayush_Interventions_for_COVID-19.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Research_and_Development_Initiatives_of_Ministry_of_Ayush_for_COVID-19.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/China's_Policy_Initiatives_fo_National_and_Global_Promotion_of_TCM.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/TKM_Study_Report.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Final_Dossier_03.01.2022_with_cover.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Concept_Note_with_cover_pages.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Ayurveda_and_Conventional_Medicine.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Document_Ayurveda.pdf
# [06:06:51] 📄 Found: http://ayushportal.nic.in/pdf/Document_Nutritional.pdf
# [06:06:51] 📄 Found: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Post_Doctoral_Fellowship_Scheme.pdf
# [06:06:51] 📄 Found: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Advt.pdf
# [06:06:51] 📄 Found: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Application%20form.pdf
# [06:06:51] 📄 Found: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Undertaking.pdf
# [06:06:51] 📄 Found: https://ayushportal.nic.in/CSS/pdf/UserManual.doc
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-5.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-7.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-8.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-3.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-4.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-6.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/CLINICAL_FINAL_REPORT-9.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-1.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-3.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-6.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-4.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-5.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-7.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-7.1.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-7.2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-7.3.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-7.4.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/DRUG_FINAL_REPORT-1.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/DRUG_FINAL_REPORT-2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-2.1.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-2.2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/Annexure-2.3.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/DRUG_FINAL_REPORT-3.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/DRUG_FINAL_REPORT-4.1.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/DRUG_FINAL_REPORT-4.2.pdf
# [06:06:53] 📄 Found: https://ayushportal.nic.in/EMR/LITERARY_FINAL_REPORT-1.pdf
# [06:06:53] 📄 Found: http://ayushportal.nic.in/pdf/12833.pdf
# [06:06:53] 📄 Found: http://ayushportal.nic.in/pdf/24216.pdf
# [06:06:53] 📄 Found: http://www.ijpsi.org/Papers/Vol2(3)/Version-1/B230508.pdf
# [06:06:53] 📄 Found: http://www.roavs.com/pdf-files/Issue-6-2013/170-178.pdf
# [06:06:53] 📄 Found: http://www.ajprd.com/currentissues_file/72.pdf
# [06:06:53] 📄 Found: http://ujconline.net/wp-content/uploads/2013/09/2-UJAHM-1322-Rv.pdf
# [06:06:53] 📄 Found: http://www.eijppr.com//api/uploads/2014/January/output/4.Novel%20and%20Synergistic%20Antinociceptive%20Activity%20of%20Different%20Compositions%20of%20Panchagavya%20and%20Aloe%20barbedansis%20Mill%20using%20Tail%20Immersion%20Model.pdf
# [06:06:53] 📄 Found: http://sphinxsai.com/Vol.3No.1/pharm_jan-mar11/pdf/PT=94(%20585-588)%20JM11.pdf
# [06:06:53] 📄 Found: http://www.asianjtm.com/qikan/manage/wenzhang/AJTM2011,6(1)-1.pdf
# [06:06:53] 📄 Found: http://www.veterinaryworld.org/Vol.4/July%20-%202011/Effect%20of%20cow%20urine%20on%20wound%20healing%20property%20in%20Wistar%20Albino%20Rats.pdf
# [06:06:53] 📄 Found: http://www.ajpcr.com/Vol5Issue1/757.pdf
# [06:06:53] 📄 Found: http://www.ijpcsonline.com/files/11-012.pdf
# [06:06:53] 📄 Found: http://www.ijppsjournal.com/Vol6Issue3/9051.pdf
# [06:06:53] 📄 Found: http://ijprs.com/download.php?file=1389893730.pdf
# [06:06:53] 📄 Found: http://www.ijrapronline.com/issues5/Anami_IJRAPR%20-%2084-87.pdf
# [06:06:53] 📄 Found: http://www.ijcpr.org/Issues/Vol3Issue2/312.pdf
# [06:06:53] 📄 Found: http://japsonline.com/admin/php/uploads/308_pdf.pdf
# [06:06:53] 📄 Found: http://www.advancedbiotech.in/628.pdf
# [06:06:53] 📄 Found: http://www.onlineijp.com/admin/fckeditor/_samples/php/article/252_120-122.pdf
# [06:06:53] 📄 Found: http://nopr.niscair.res.in/bitstream/123456789/8105/1/NPR%204(4)%20270-273.pdf
# [06:06:53] 📄 Found: http://www.ajbpr.com/issues/volume2/issue2/FINAL%2024.pdf
# [06:06:53] 📄 Found: http://files.figshare.com/1631716/A0710108.pdf
# [06:06:53] 📄 Found: http://nopr.niscair.res.in/bitstream/123456789/5074/1/IJTK%208(3)%20387-391.pdf
# [06:06:53] 📄 Found: http://aygrt.isrj.org/UploadedData/909.pdf
# [06:06:53] 📄 Found: http://www.besjournal.com/freeArticles/pastIssues/2006/No6/200706/P020070628701276609851542006614713.pdf
# [06:06:53] 📄 Found: http://www.besjournal.com/freeArticles/pastIssues/2004/No3/200701/P0200701106997172402297720041731758.pdf
# [06:06:53] 📄 Found: http://www.isah-soc.org/documents/2005/sections/19_vol_2.pdf
# [06:06:53] 📄 Found: http://crdeep.com/wp-content/uploads/2012/10/Vol-1-3-1-IJBAS.pdf
# [06:06:53] 📄 Found: http://scholarsresearchlibrary.com/DPL-vol3-iss2/DPL-2011-3-2-507-513.pdf
# [06:06:53] 📄 Found: http://omicsonline.org/2157-7579/2157-7579-S1.004-033.pdf
# [06:06:53] 📄 Found: http://nopr.niscair.res.in/bitstream/123456789/27935/1/IJTK%2013(2)%20398-403.pdf
# [06:06:53] 📄 Found: http://www.gjournals.org/GJAS/GJAS%20Pdf/2013/May/031313523%20Tanimu%20et%20al.pdf
# [06:06:53] 📄 Found: http://nopr.niscair.res.in/bitstream/123456789/8069/1/NPR%204(2)%20102-106.pdf
# [06:06:53] 📄 Found: http://cropandweed.com/vol7issue2/pdf/18.pdf
# [06:06:53] 📄 Found: http://urpjournals.com/tocjnls/27_13v3i1_11.pdf
# [06:06:53] 📄 Found: http://www.jofamericanscience.org/journals/am-sci/am0602/07_1124_paper_am0602.pdf
# [06:06:53] 📄 Found: http://govigyan.com/Images/res3.pdf
# [06:06:53] 📄 Found: http://www.academicjournals.org/article/article1383841908_Srimathi%20et%20al.pdf
# [06:06:53] 📄 Found: http://www.academicjournals.org/article/article1386058722_Naik%20et%20al.pdf
# [06:06:53] 📄 Found: http://idosi.org/gjer/gjer6(2)12/5.pdf
# [06:06:53] 📄 Found: http://www.researchjournal.co.in/Online/TAJH/TAJH%205(2)/5_A-307-308.pdf
# [06:06:53] 📄 Found: http://amarillo.tamu.edu/files/2010/10/Cattle-Manure-for-energy.pdf
# [06:06:53] 📄 Found: http://www.researchjournal.co.in/online/AJBS/AJBS%206(2)/6_A-258-259.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Protocol_Text.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/faq-covid-protocol-Revised.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/books/6831.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Bulletin/NewsLetter1.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Bulletin/NewsLetter2.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Bulletin/NewsLetter3.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Bulletin/NewsLetter4.pdf
# [06:06:57] 📄 Found: https://ksuwssb.karnataka.gov.in/frontend/opt1/images/covid/instructions%20notices/advice_9.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Corona_Covid19.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Corona_Covid19_2.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/AAROKYAM.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/CCIM_Telemedicine_Guidelines_08-04-2020.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Telemedicine_Practice_guidelines_CCH.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Ayush_Practitioner_Guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Clinical_Protocol_Guideline_Document_and_Annexures.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/ayurveda-guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/yoga-guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/naturopathy-guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/unani-guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/siddha-guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Homeopathy_guidelines.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/AdvisoryforHRmanagement.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Covid_19_facilitator_guide.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Guidelines_for_Quarantine_facilities.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Guidelineson_ClinicalManagement_of_COVID19.pdf
# [06:06:57] 📄 Found: http://www.ccras.nic.in/sites/default/files/Notices/25042020_Letter_to_States_UTs_for_Ayush_Kwath.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Panchakarma_Technicians_2.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Food_Recipes_From_Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/Ayush_Advisory_Maharashtra.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/26.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/27.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/28.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/29.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/30.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/31.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/32.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/33.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/pdf/34.Ayush.pdf
# [06:06:57] 📄 Found: http://ayushportal.nic.in/CSS/pdf/UserManual.doc
# [06:06:59] 📚 Total found: 124
# [06:07:00] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/4cd5676db0.json
# [06:07:04] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/7808dfb53b.json
# [06:07:05] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/fc42f8f94c.json
# [06:07:05] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/054303b376.json
# [06:07:06] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/8e38633952.json
# [06:07:06] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/b650c9398a.json
# [06:07:08] ❌ Download failed: http://nopr.niscair.res.in/bitstream/123456789/8069/1/NPR%204(2)%20102-106.pdf -> Cannot connect to host nopr.niscair.res.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:07:08] ❌ Download failed: http://www.ccras.nic.in/sites/default/files/Notices/25042020_Letter_to_States_UTs_for_Ayush_Kwath.pdf -> Cannot connect to host www.ccras.nic.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:07:13] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/7836c5c0bb.json
# [06:07:14] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/c8a8819c7e.json
# [06:07:15] 🔍 No text found, using OCR
# [06:07:58] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/234ae21d22.json
# [06:08:02] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/265292c4a0.json
# [06:08:04] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/03a864aa2e.json
# [06:08:04] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/02754cff9e.json
# [06:08:05] ❌ Download failed: http://nopr.niscair.res.in/bitstream/123456789/5074/1/IJTK%208(3)%20387-391.pdf -> Cannot connect to host nopr.niscair.res.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:08:07] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/8249814603.json
# [06:08:09] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/17dbbe193f.json
# [06:08:10] ❌ Download failed: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Post_Doctoral_Fellowship_Scheme.pdf -> Cannot connect to host ccras.nic.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:08:14] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/ca511ff628.json
# [06:08:16] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/9fa9cb14d0.json
# [06:08:22] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/3a7a025507.json
# [06:08:24] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/3ebb51d853.json
# [06:08:25] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/6ef37db051.json
# [06:08:25] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/a605b8735d.json
# [06:08:26] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/5da975dcb3.json
# [06:08:29] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/cadc0cbc12.json
# [06:08:30] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/0e37126003.json
# [06:08:31] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/26d36bb27d.json
# [06:08:33] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/b972f3fcf8.json
# [06:08:36] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/90d20d0361.json
# [06:08:37] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/97c0fc48d0.json
# [06:08:41] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/3b7ae5fbf2.json
# [06:08:42] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/873a2d9030.json
# [06:08:43] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/0d58b868ae.json
# [06:08:44] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/e816f73b19.json
# [06:08:49] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/736c5dcfa6.json
# [06:08:54] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/6b3a8bf7fe.json
# [06:08:56] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/8566c4f630.json
# [06:09:04] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/2089642940.json
# [06:09:07] ❌ Download failed: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Application%20form.pdf -> Cannot connect to host ccras.nic.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:09:08] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/fd9443e061.json
# [06:09:10] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/9f58917691.json
# [06:09:11] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/71f68505ac.json
# [06:09:14] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/c10665293b.json
# [06:09:15] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/4175dd0103.json
# [06:09:15] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/927aaa6357.json
# [06:09:15] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/e9b6b20327.json
# [06:09:16] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/686fb3a70b.json
# [06:09:18] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/5b3fb28f8b.json
# [06:09:20] 🔍 No text found, using OCR
# [06:09:56] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/1141e26ed1.json
# [06:10:00] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/2c1c1d2fff.json
# [06:10:11] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/6f72566f07.json
# [06:10:13] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/e170f4faab.json
# [06:10:15] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/6c5936cadc.json
# [06:10:20] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/a0d610ab03.json
# [06:10:21] ❌ Download failed: https://ksuwssb.karnataka.gov.in/frontend/opt1/images/covid/instructions%20notices/advice_9.pdf -> Cannot connect to host ksuwssb.karnataka.gov.in:443 ssl:default [Connection reset by peer]
# [06:10:22] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/4620875246.json
# [06:10:23] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/bb1db677e1.json
# [06:10:24] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/ced3910ca7.json
# [06:10:29] 🔍 No text found, using OCR
# [06:14:20] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/6c31b1b921.json
# [06:14:20] ❌ Download failed: https://ayushportal.nic.in/EMR/PRECLINICAL_FINAL_REPORT-4.pdf ->
# [06:14:20] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/dcdc34d105.json
# [06:14:20] 🔍 No text found, using OCR
# [06:14:21] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/38b729129b.json
# [06:14:21] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/b630bdd13d.json
# [06:14:21] ❌ Download failed: http://www.asianjtm.com/qikan/manage/wenzhang/AJTM2011,6(1)-1.pdf -> Cannot connect to host www.asianjtm.com:80 ssl:default [Name or service not known]
# [06:14:24] 🔍 No text found, using OCR
# [06:14:24] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/7c2f74031a.json
# [06:14:26] ❌ Download failed: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Undertaking.pdf -> Cannot connect to host ccras.nic.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:14:26] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/886a961caf.json
# [06:14:34] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/e06de86b08.json
# [06:14:36] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/0ddffd3b97.json
# [06:14:37] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/c03555a7ce.json
# [06:14:38] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/7f368179f0.json
# [06:14:38] 🔍 No text found, using OCR
# [06:18:13] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/ba0569ccc4.json
# [06:18:13] ❌ Download failed: http://amarillo.tamu.edu/files/2010/10/Cattle-Manure-for-energy.pdf ->
# [06:18:15] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/c01c3cceff.json
# [06:18:27] ❌ Download failed: http://nopr.niscair.res.in/bitstream/123456789/27935/1/IJTK%2013(2)%20398-403.pdf -> Cannot connect to host nopr.niscair.res.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:18:38] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/00f2a498e2.json
# [06:18:41] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/116d91baa5.json
# [06:18:42] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/2763960211.json
# [06:18:42] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/5d2137235e.json
# [06:18:46] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/ed4bdb5749.json
# [06:18:46] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/627c23ecf6.json
# [06:18:47] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/10c73168ff.json
# [06:19:13] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/c6cb82e8f5.json
# [06:19:14] ❌ Download failed: http://ayushportal.nic.in/pdf/Document_Nutritional.pdf ->
# [06:19:15] ❌ Download failed: http://nopr.niscair.res.in/bitstream/123456789/8105/1/NPR%204(4)%20270-273.pdf -> Cannot connect to host nopr.niscair.res.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:19:19] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/68206dfb43.json
# [06:19:19] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/446063387e.json
# [06:19:20] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/51a47ed66e.json
# [06:19:20] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/80c88a73ed.json
# [06:19:21] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/4bf6e6003f.json
# [06:19:27] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/4c2a312750.json
# [06:19:27] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/82dfea21a3.json
# [06:19:32] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/0533851451.json
# [06:19:33] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/314b98915a.json
# [06:19:33] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/b3a98048e3.json
# [06:19:40] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/82c1f9f35e.json
# [06:19:45] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/98f506d6d6.json
# [06:19:47] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/8db8d6dc1c.json
# [06:19:52] 🔍 No text found, using OCR
# [06:22:55] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/bc1a091c24.json
# [06:22:55] ❌ Download failed: http://ayushportal.nic.in/pdf/Document_Ayurveda.pdf ->
# [06:23:01] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/34c43445b9.json
# [06:23:07] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/cfd9ee1f56.json
# [06:23:07] ❌ Download failed: http://ccras.nic.in/sites/default/files/Notices/03112021_CCRAS_Advt.pdf -> Cannot connect to host ccras.nic.in:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')]
# [06:23:07] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/ac952dd219.json
# [06:23:08] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/24e6352dcf.json
# [06:23:09] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/8d3b1c8302.json
# [06:23:10] 🔍 No text found, using OCR
# [06:26:40] 📝 Saved: /content/drive/MyDrive/sanskritdocs/outputs/3bf5aec4e6.json
# [06:26:40] ❌ Download failed: http://ayushportal.nic.in/pdf/Compendium_of_select_research_publications_on_the_Ayush_Interventions_for_COVID-19.pdf ->
# [06:26:40] ✅ Done.
